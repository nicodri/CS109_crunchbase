# %%
import requests
import time
import json

def get_json(url):
    r_ = requests.get(url)
    try:
        return r_.json()
    except ValueError:
        time.sleep(1)
        return get_json(url)

user_key = <INSERT KEY HERE>

# %% [markdown]
# # Organizations

# %%
r = requests.get('https://api.crunchbase.com/v/3/organizations?user_key={}'.format(user_key))

# %%
r.json()['data']['paging']
# Out:
# {u'current_page': 1,
#  u'items_per_page': 100,
#  u'next_page_url': u'https://api.crunchbase.com/v/3/organizations?page=2',
#  u'number_of_pages': 4086,
#  u'prev_page_url': None,
#  u'sort_order': u'created_at DESC',
#  u'total_items': 408579}

# %%
r.json()['data']['items'][0]
# Out:
# {u'properties': {u'api_path': u'organizations/africa-consulting-trading',
#   u'city_name': None,
#   u'country_code': None,
#   u'created_at': 1448335501,
#   u'domain': u'act-afrique.com',
#   u'facebook_url': None,
#   u'homepage_url': u'http://www.act-afrique.com',
#   u'linkedin_url': None,
#   u'name': u'Africa Consulting & Trading',
#   u'permalink': u'africa-consulting-trading',
#   u'primary_role': u'company',
#   u'profile_image_url': u'http://public.crunchbase.com/t_api_images/v1448335489/xdrsfaiuew98lphqhmlo.png',
#   u'region_name': None,
#   u'short_description': u'ACT is the culmination of a long journey marked by the passion of its founder and its partners for Africa and its development.',
#   u'twitter_url': None,
#   u'updated_at': 1448335502,
#   u'web_path': u'organization/africa-consulting-trading'},
#  u'type': u'OrganizationSummary',
#  u'uuid': u'5bca314aef44c11c0e51c394c05330f6'}

# %%
organizations = r.json()['data']['items']

# %%
len(organizations)
# Out:
# 72000

# %% [markdown]
# Script to scrap all the organizations, took arount 5 hours (because of the API bandwith)

# %%
organizations = []
for i in xrange(1, 4087):
    link = 'https://api.crunchbase.com/v/3/organizations?page={}&user_key={}'.format(i, user_key)
    if i%100 == 0:
        print 'page ', i, ' length is ',len(organizations)
    r_json = get_json(link)
    organizations += r_json['data']['items']
    time.sleep(0.1)

with open('tmp/organizations_json.json', 'w') as f:
    json.dump(organizations, f)
# Out:
# page  3400  length is  3300
# page  3500  length is  13300
# page  3600  length is  23300
# page  3700  length is  33300
# page  3800  length is  43300
# page  3900  length is  53300
# page  4000  length is  63300

# %%
# map from the permalink of a company to its index in the list organizations_tot
permalink2index = {organizations_tot[i]['properties']['permalink']: i for i in xrange(len(organizations_tot))}

# %%
permalink2index
# Out:
# {u'd-n-laoghaire-institute-of-art-design-and-technology': 173561,
#  u'gmc-truck': 70047,
#  u'mdbg': 310707,
#  u'hoyer-associates': 190470,
#  u'harley-co': 297303,
#  u'westrock-trading': 16248,
#  u'mdbn': 86550,
#  u'digital-rockers': 81687,
#  u'bloom-company': 33835,
#  u'fantasy-shopper': 336237,
#  u'papatv-cn': 48763,
#  u'phoenix-rehabilitation-and-health-services': 44445,
#  u'napcon-associates': 282300,
#  u'paizo': 102319,
#  u'paiza': 88443,
#  u'talontax': 191624,
#  u'savvify': 178490,
#  u'searchsense': 161250,
#  u'godaam': 308299,
#  u'human-rights-foundation': 74716,
#  u'artmachine-inc': 280015,
#  u'bigbelly-solar': 235125,
#  u'dw-healthcare-partners': 297915,
#  u'american-farmland': 11984,
#  u'bluetree-capital-group': 388513,
#  u'reconquistar-editora': 22047,
#  u'fundation': 281763,
#  u'sleeklighting': 163876,
#  u'xodo': 70433,
#  u'mayartech': 208825,
#  u'ceph-storage': 326240,
#  u'american-health-information-management-association': 185980,
#  u'dockbit': 38283,
#  u'regency-beauty-institute-darien': 170905,
#  u'yogablue': 331481,
#  u'vln-media': 354277,
#  u'spanatix': 342105,
#  u'mobila-la-comanda': 95774,
#  u'ascension-college': 175082,
#  u'router-solutions': 45786,
#  u'spider9': 128239,
#  u'weelo': 15695,
#  u'weeli': 65061,
#  u'brothers-magoo': 120804,
#  u'weele': 235798,
#  u'ivaco-rolling-mills': 185519,
#  u'imedical-apps': 102246,
#  u'metaldyne-corporation': 209023,
#  u'home-support-services': 209385,
#  u'vaish-at-rivoli': 67275,
#  u'rhythm-services-network': 396703,
#  u'fidor-tecs-ag': 89308,
#  u'consult-hire': 116462,
#  u'knighthead-funding': 111653,
#  u'the-julie-kinnear-toronto-real-estate-team': 296211,
#  u'rr-donnelley-roundtable': 148410,
#  u'ratekhoj-com': 384104,
#  u'ridings-early-growth-investment': 389368,
#  u'microban-international': 17098,
#  u'simply-aware': 90101,
#  u'brazil-warrant': 404954,
#  u'tumblon': 399101,
#  u'novobeat': 20937,
#  u'mymensi-com': 354903,
#  u'ecopia-tech-corporation': 11022,
#  u'tpg-internet': 213376,
#  u'nourish-care-systems': 4998,
#  u'newmans-business-accelerator': 129041,
#  u'skilljam': 271138,
#  u'tarocchi-on-line': 129280,
#  u'the-artificial': 182069,
#  u'raven-biotechnologies': 382215,
#  u'cardia-access': 196486,
#  u'skilljar': 268531,
#  u'rover-company': 248445,
#  u'mfrtech': 112547,
#  u'dr-wolch-holistic-dentistry-toronto': 189511,
#  u'thengine-co': 203789,
#  u'phoenix-seminary': 172934,
#  u'filesgateway-com': 217342,
#  u'inventwheel': 395382,
#  u'neoconix': 393942,
#  u'rocqup': 49219,
#  u'eocycle': 66589,
#  u'manglam-education-b-ed-admission-b-ed-institute-delhi': 11431,
#  u'alliance-for-downtown-new-york': 323661,
#  u'redshift-writers': 300008,
#  u'scoot-doodle': 323385,
#  u'studentbox': 392330,
#  u'hotelrunner': 118058,
#  u'kerala-state-industrial-development-corporation': 75351,
#  u'zoompal': 335098,
#  u'crock': 372578,
#  u'helium-development': 12408,
#  u'southern-custom-painting': 204133,
#  u'mytripkarma': 32270,
#  u'zero-motorcycles': 389155,
#  u'crowdhaven': 2591,
#  u'eb5visa': 17635,
#  u'indie-tv': 160889,
#  u'dog-walking-battersea': 50024,
#  u'flex-perks': 78850,
#  u'palmer-worldwide': 242797,
#  u'l-a-casting': 377112,
#  u'semanttica': 161630,
#  u'flatbooster': 297526,
#  u'emaar-mgf': 382732,
#  u'carryonmall': 125656,
#  u'inverse-ink': 336813,
#  u'digital-courier': 265193,
#  u'skybound-entertainment': 100504,
#  u'seiva-technologies': 41359,
#  u'airespring': 294179,
#  u'ebags-com-2': 94840,
#  u'lively-up-media': 343622,
#  u'zipments': 338650,
#  u'urbanbaby': 285144,
#  u'louisiana-technical-college-west-monroe': 171172,
#  u'onemma': 199439,
#  u'delivery-republic': 4557,
#  u'tv-globo': 275788,
#  u'webdoctor': 61818,
#  u'banque-bruxelles-lambert': 234526,
#  u'checkinmd': 71761,
#  u'diversitech': 118503,
#  u'sidebark': 314008,
#  u'dancesport-innovations': 331124,
#  u'fti-international': 215608,
#  u'wireless-bluetooth-keyboard': 156976,
#  u'twenty19': 340278,
#  u'trax-capital': 18312,
#  u'bgitl': 336473,
#  u'jesuit-school-of-theology-at-berkeley': 175720,
#  u'yahoo': 407393,
#  u'hormann-uk-ltd': 216937,
#  u'national-science-teachers-association': 202373,
#  u'sept-mille-sarl': 242458,
#  u'ipk-berlin': 12438,
#  u'monster-minds-media-sas': 242908,
#  u'echelon': 347048,
#  u'photogram-me': 340736,
#  u'reklamface': 195022,
#  u'equus-management': 206366,
#  u'coffeejobs': 3429,
#  u'beergram': 315618,
#  u'hawaii-oceanic-technology': 74240,
#  u'kraft-jacobs-suchard': 264682,
#  u'clientflow': 210839,
#  u'1st-all-around': 203684,
#  u'deskovery': 102673,
#  u'lawrence-family-medical-practice': 129614,
#  u'planet-pilot': 113190,
#  u'homework-guiders': 38885,
#  u'askedweb': 393369,
#  u'robrady-design': 45828,
#  u'flowapp': 53431,
#  u'techhub-connent-a-project-of-punjab-information-technology-board': 29436,
#  u'meditrina-pharmaceuticals-inc': 275147,
#  u'waste-central': 394671,
#  u'360-capital-partners': 404744,
#  u'huntington-learning-centers': 192565,
#  u'avg-antivirus-installation-error-1-855-233-7309-avg-antivirus-customer-service-toll-free-number-usa': 39254,
#  u'zolbi': 317059,
#  u'tothepoint-solution': 358472,
#  u'we-are-on-a-boat': 145001,
#  u'coda-center-for-digital-archaeology': 285050,
#  u'glentwood': 246004,
#  u'activeword-systems': 377953,
#  u'learn-something': 382505,
#  u'capsule-seo-montreal': 132248,
#  u'rcg-infosoft-pvt-ltd': 273248,
#  u'hoodoko': 192674,
#  u'multiso-multimedia-solutions': 387893,
#  u'saint-marys-university-of-minnesota': 168745,
#  u'scr-engineers': 103600,
#  u'printcafe-software': 146262,
#  u'advercar': 307027,
#  u'unicard': 300089,
#  u'desert-wolf': 60717,
#  u'pacecode-technologies': 394376,
#  u'sofa-entertainment': 304898,
#  u'grafyt': 149501,
#  u'penser-consulting-limited': 76569,
#  u'reva-capital': 205751,
#  u'alexandria-startup-cup': 198542,
#  u'cloudtenna': 186761,
#  u'messageway-solutions': 365801,
#  u'oberon-media': 395973,
#  u'greylon': 78126,
#  u'zetchi': 255962,
#  u'ouroboros': 196227,
#  u'lookbook-cloud': 224087,
#  u'dover-management-services-ltd': 192624,
#  u'veri-yaz\u0131l\u0131m-proje-dan\u0131\u015fmanl\u0131k-hiz-san-ve-tic-a-\u015e-': 107795,
#  u'fortis-college-richmond': 170263,
#  u'nispera': 42427,
#  u'virtocommerce': 293708,
#  u'global-asset-capital': 403401,
#  u'accel-technology': 8650,
#  u'haspa-bgm': 44117,
#  u'cueva-digital': 203424,
#  u'apparel-us': 306341,
#  u'desa-kreativ': 50757,
#  u'levy-family-partners': 154055,
#  u'caricme': 116801,
#  u'beijing-netposa-technologies-co-ltd': 178843,
#  u'vastera': 356212,
#  u'eight-international': 104781,
#  u'elisra': 289402,
#  u'welcomed': 45286,
#  u'czechinvest': 81889,
#  u'jaypee-university-of-information-technology': 167984,
#  u'ascension-insurance-inc': 220700,
#  u'gomotion-inc': 383070,
#  u'visuality': 31770,
#  u'iletyou': 398003,
#  u'infofac': 62970,
#  u'rushsoft': 245824,
#  u'giftoman': 25867,
#  u'tarkenton-companies': 212094,
#  u'welcomer': 106346,
#  u'fis': 348989,
#  u'fip': 16267,
#  u'urbanzing-com': 355077,
#  u'fort-valley-state-university': 170447,
#  u'lonestar-patio-builders': 91089,
#  u'fiz': 286657,
#  u'real-time-innovations': 378764,
#  u'fix': 377471,
#  u'ionis-education-group': 187749,
#  u'newcommbiz': 258814,
#  u'optimimo': 277101,
#  u'spinealign-medical': 381996,
#  u'fig': 137265,
#  u'freann-financial-services-limited': 334416,
#  u'fin': 51899,
#  u'fio': 262291,
#  u'acecla-technology-ltd': 301041,
#  u'encodingall': 333329,
#  u'carzuel': 70474,
#  u'health-technology-assessment-international': 29357,
#  u'publidex': 71830,
#  u'pickle-io': 160549,
#  u'unbranded-designs': 143688,
#  u'artists-clothing': 111966,
#  u'sovi': 164677,
#  u'meiji-yasuda-life-insurance-company': 202552,
#  u'sova': 156883,
#  u'arizona-state-university-online-school': 175379,
#  u'crosscomm': 301780,
#  u'globaltranz': 351055,
#  u'rapt-studio': 253414,
#  u'timber-construction-co': 257143,
#  u'teachvr-2': 36844,
#  u'the-matador-media': 366768,
#  u'etalkup': 400439,
#  u'ulead-corporation': 256863,
#  u'altair-engineering': 356037,
#  u'blend-web-mix': 122764,
#  u'toptalent-in': 237951,
#  u'papaya-apps': 245012,
#  u'las-gralarias-foundation': 74709,
#  u'limousin-participation': 308942,
#  u'team-ruby-henderson': 189515,
#  u'asustek-holdings': 375381,
#  u'sigma-capital-partners': 346948,
#  u'musafir-com': 84817,
#  u'startup-experience-2': 92543,
#  u'sems-technologies': 39029,
#  u'palisades-associates-inc': 279344,
#  u'mount-vernon-city-school-district': 16291,
#  u'dooers': 87875,
#  u'hire-a-genie': 62309,
#  u'crowd-favorite': 376199,
#  u'bullet-time-ventures-ii': 178841,
#  u'empire-energy-management-systems': 180131,
#  u'kown': 155657,
#  u'buttercups': 46452,
#  u'webmindz24': 401232,
#  u'inmed-s-a': 38104,
#  u'palm-beach-ice-works': 221662,
#  u'connor-clark-lunn-financial-group': 19372,
#  u'cadient-group': 289011,
#  u'freelancers-outpost': 212009,
#  u'mattress-firm-edgemont': 7308,
#  u'onshore-ems': 18286,
#  u'triplehop-technologies': 352442,
#  u'affordable-leaflets': 21077,
#  u'adcopy': 367613,
#  u'climadix': 385248,
#  u'the-dii-group': 220515,
#  u'shazzle': 379707,
#  u'abbott': 399951,
#  u'stagwell-group': 16238,
#  u'action-for-business': 7836,
#  u'gestamp-north-america': 266260,
#  u'indiemark': 197186,
#  u'logiciel-information-systems': 248356,
#  u'q-dispatch-dispatch-software': 213151,
#  u'shapiro-goldman-babboni-walsh': 160484,
#  u'pcsx2': 104842,
#  u'parkson': 75225,
#  u'tigmus-this-is-good-music': 133168,
#  u'capital-ventures': 279229,
#  u'weelp': 111458,
#  u'midland-mechanical-inc': 184895,
#  u'tickermachine': 62452,
#  u'bookmark': 90704,
#  u'7-ventures': 236002,
#  u'dtpindesignservices': 153647,
#  u'momment': 334430,
#  u'social-fulcrum': 287271,
#  u'athoz-thought-care': 60,
#  u'synbotics': 196321,
#  u'superantispyware': 393880,
#  u'deligic': 226363,
#  u'pretty-posts': 375033,
#  u'payintech': 147838,
#  u'medeel': 296930,
#  u'gesher-consulting-hr': 384357,
#  u'cto-forum': 362957,
#  u'kidspot': 339626,
#  u'aegis-fuel': 195325,
#  u'omnidate': 402971,
#  u'poker-players-international': 39758,
#  u'oxient-technologies': 216746,
#  u'powtoonpro': 101626,
#  u'procom-technology': 372538,
#  u'the-new-york-times': 88687,
#  u'ernst-young-entrepreneurial-consulting-group': 288954,
#  u'smythe-ratcliffe': 110680,
#  u'blue-cross-and-blue-shield-of-north-carolina': 55413,
#  u'adiante-ventures': 240802,
#  u'applegate-business-directory': 310610,
#  u'ivinci-partners': 165296,
#  u'enteprise-educators-uk': 91807,
#  u'opera-telecom': 253388,
#  u'call-1-888-683-4880-bellsouth-email-customer-support-phone-number': 6106,
#  u'offis-institute-for-information-technology': 21647,
#  u'flickle-movie-recommendation': 23465,
#  u'bcisive': 404869,
#  u'transportrent-lt': 38608,
#  u'little-helper': 38064,
#  u'healthiest-employer': 43524,
#  u'yachtspanic-com-by-interpanic': 295516,
#  u'keith-l-magness-llc': 302534,
#  u'esb-international': 287308,
#  u'national-quality-forum': 9019,
#  u'vallila-interior': 46451,
#  u'tidepool': 320827,
#  u'a-steroids': 397989,
#  u'adsl-movil-es': 389704,
#  u'useeng': 42751,
#  u'manchester-community-college': 170676,
#  u'the-school-of-massage-therapy-at-solex': 173825,
#  u'david-kremin-associates-p-c': 93036,
#  u'empower2adapt': 126082,
#  u'colorado-advanced-technology-institute': 220197,
#  u'verifcient-technologies': 201518,
#  u'aquinox-pharmaceuticals': 365697,
#  u'sambasafety': 248731,
#  u'mont-nebo-ltd-company-for-e-commerce': 82120,
#  u'i-hit-it-big': 381010,
#  u'idea-soft': 124288,
#  u'next-level-optical-2': 75311,
#  u'specs-direct': 35731,
#  u'monta-vista-capital': 36672,
#  u'dr-pepper-snapple-group': 229813,
#  u'qudos-visuals': 28474,
#  u'roqbot': 348968,
#  u'marrying-mr-darcy': 128263,
#  u'amss-limited': 48345,
#  u'robert-w-jones-iii-p-c': 344583,
#  u'bellybaloo': 318299,
#  u'avidal-vascular-gmbh': 85199,
#  u'jupiter-telecommunications-j-com': 374671,
#  u'geekdom-fund': 281488,
#  u'euclid-infotech': 402548,
#  u'william-morris-agency': 403901,
#  u'accentium-web-pvt-ltd': 279401,
#  u'kehalim': 397120,
#  u'apex-plaza': 146853,
#  u'human-telex': 50097,
#  u'yogatraveller-com': 180775,
#  u'scientific-systems': 103892,
#  u'flatsoft-displays': 587,
#  u'chelsea-green-publishing': 277282,
#  u'overnight-asia': 41228,
#  u'pci-health-training-center': 173567,
#  u'islamic-world-entrepreneurs-network-iswen': 30474,
#  u'property-tax-relief-corporation': 137251,
#  u'canadas-mastermind-development-corporation': 325900,
#  u'catholic-charities': 87785,
#  u'kirkus-reviews': 285345,
#  u'callerads-limited': 143732,
#  u'calm-response': 361693,
#  u'detention-apps': 244269,
#  u'rentobo': 317081,
#  u'snip-ly': 363816,
#  u'mobaloo': 200341,
#  u'mobalon': 129565,
#  u'isec7': 141953,
#  u'delaware-business-roundtable': 69887,
#  u'the-law-office-of-jonathan-h-maisel-pc': 111036,
#  u'alitify': 231738,
#  u'kissell-blake': 276117,
#  u'hbe-software': 360144,
#  u'apsiyon': 325270,
#  u'tate-rehmet-law-office-p-c': 291514,
#  u'steeger-engineering': 303044,
#  u'evollia': 311156,
#  u'shopkolo-com': 326840,
#  u'fashion-blogger': 183747,
#  u'kenner-company': 21540,
#  u'meality': 281416,
#  u'efficas': 211481,
#  u'national-cheng-kung-university-2': 190290,
#  u'onlessons-com': 298656,
#  u'nettle': 357302,
#  u'optimal-workshop': 76815,
#  u'g-caffe': 214869,
#  u'visit-it-later': 293520,
#  u'healthcare-impact-associates': 286799,
#  u'ideaxplosion': 73551,
#  u'bird-design-limited': 1807,
#  u'btd-group': 274454,
#  u'endicia': 81559,
#  u'the-crossbow-store': 253766,
#  u'cyp-design': 223705,
#  u'bmw-brilliance-automotive': 258899,
#  u'fernuniversit-t-hagen': 171346,
#  u'surecruise-com': 251966,
#  u'futurewave-software': 254277,
#  u'managedway': 57257,
#  u'tiktakto': 286989,
#  u'wunderman': 337083,
#  u'samir-j-naik-dds': 344475,
#  u'blue-flame-data': 357622,
#  u'venari-resources': 143885,
#  u'spts-technologies': 265082,
#  u'startup-oasis': 80550,
#  u'entrepreneurial-spark': 197680,
#  u'lindhard': 267285,
#  u'medpagetoday': 381090,
#  u'ifs-capital-malaysia-sdn-bhd': 46253,
#  u'festivalfox': 345490,
#  u'cohesive-technology-solutions': 251153,
#  u'metecol': 310351,
#  u'homusdeco': 30488,
#  u'heartsounds': 373868,
#  u'servpro-of-phoenix': 227851,
#  u'limelightlife': 220440,
#  u'masstlc-education-foundation': 104591,
#  u'topanga-technologies': 382887,
#  u'ideeli': 406989,
#  u'fisheries-development-authority': 289371,
#  u'republic-moving---storage': 78053,
#  u'3innovate': 349564,
#  u'sketchpile': 215797,
#  u'china-f-b': 55679,
#  u'catholic-healthcare-west': 228555,
#  u'gamesdrone': 144060,
#  u'maverick-game': 33711,
#  u'sienna-biotech-inc': 272367,
#  u'water-for-good': 66004,
#  u'b-good': 91692,
#  u'ndc-group': 263611,
#  u'oakley-network': 279838,
#  u'isaac-newton-school-tumbes': 70261,
#  u'wriota': 155192,
#  u'san-antonio-independent-school-district': 35278,
#  u'csis-security-group': 104295,
#  u'oriental-photo-models': 30197,
#  u'radiant-color': 107915,
#  u'presstek': 266719,
#  u'the-college-of-wooster': 174407,
#  u'sassypaw': 188677,
#  u'first-capital-partners': 334514,
#  u'codex-oncology': 105658,
#  u'beatstars': 238159,
#  u'metal-lynx': 105247,
#  u'seeds-2': 67294,
#  u'walk-ons-bistreaux-bar': 264373,
#  u'global-one-communications-llc': 283455,
#  u'rhinobird': 46962,
#  u'daniel-s-jewelers': 110541,
#  u'browsertap': 300407,
#  u'national-genetics-institute': 262210,
#  u'sigma-infosolutions': 307954,
#  u'shaidee': 54117,
#  u'12engines': 163555,
#  u'navigation-info-kft': 244622,
#  u'multiple-capital': 387416,
#  u'kids-online-america': 254062,
#  u'frontier-toxicology': 266553,
#  u'zestbuds': 194494,
#  u'wimark-systems': 109562,
#  u'sostariffe': 58951,
#  u'web-design-melbourne': 328058,
#  u'belae-brands': 231258,
#  u'owni-france': 156213,
#  u'infersystems': 85196,
#  u'hockeystickman': 47008,
#  u'posco-bioventures': 387740,
#  u'tile-international': 300649,
#  u'golfit-at': 385203,
#  u'healthworks-my': 54098,
#  u'tibco-software-inc': 404270,
#  u'abcteach-com': 355335,
#  u'dreamquark': 74099,
#  u'hea-employment-com': 197664,
#  u'dutch-connection': 250101,
#  u'florida-investment-network-3': 115567,
#  u'florida-investment-network-2': 115568,
#  u'3ding': 90736,
#  u'paradigm-group-inc-(pgi)': 112197,
#  u'dining-downunder-cooking-show': 288793,
#  u'qicheqiche': 362357,
#  u'go2mobi': 313144,
#  u'visit-milwaukee': 38871,
#  u'ziggeo': 88700,
#  u'billiger-de': 101809,
#  u'scoreboard-social': 297250,
#  u'superfund-asset-management': 248392,
#  u'kirloskar-integrated-technologies-ltd': 284009,
#  u'noble-markets': 75968,
#  u'rider-university-2': 170132,
#  u'giglinx': 156804,
#  u'om-group': 376508,
#  u'on-line-monitoring': 367069,
#  u'portfoliodashboards': 329772,
#  u'goachiev': 302779,
#  u'instagator': 111562,
#  u'bamboo-bucharest': 161568,
#  u'mooneye-advisors-srl': 30497,
#  u'mocean-mobile': 327109,
#  u'remuneration-and-nomination-committees': 269275,
#  u'ikeepsafe': 183710,
#  u'salesoar': 85704,
#  u'ripple-platform': 310856,
#  u'microcad': 4396,
#  u'sisters-code': 77506,
#  u'guidefitter': 165383,
#  u'indiana-university-purdue-university-at-indianapolis': 148280,
#  u'farfromhomepage': 314769,
#  u'kdenlive': 76876,
#  u'fibroblast': 319301,
#  u'silentium': 394339,
#  u'songspace': 226778,
#  u'ladytime-pl': 66955,
#  u'open-information-systems-ois': 188398,
#  u'river-studio': 240538,
#  u'erelyx': 203756,
#  u'hottest-on-campus': 362378,
#  u'wrong-way-pictures': 70592,
#  u'sisaptec': 198670,
#  u'ichessu': 159624,
#  u'oilfiltersonline-com': 349543,
#  u'two-river': 41434,
#  u'pb-j-labs': 148048,
#  u'corrpro-companies': 27316,
#  u'saferyde': 5868,
#  u'boston-university-photonics-center': 207644,
#  u'sailer-interactive': 1215,
#  u'jaldi-semiconductor': 209947,
#  u'majid': 18958,
#  u'gt-relentless-llc': 59103,
#  u'pogo-customer-service-number-1-844-446-4460-pogo-help-phone-number-some-times-pogo-games-2': 674,
#  u'naviant': 289029,
#  u'i-predictus': 260474,
#  u'everlast-worldwide': 12208,
#  u'myreta-com': 212930,
#  u'umnius': 92865,
#  u'unoh': 360074,
#  u'fobal-corporation': 357825,
#  u'ip-holdings': 198825,
#  u'orbund': 235436,
#  u'quikrinfo-free-classified-ads': 200789,
#  u'epul-se': 322172,
#  u'vechos': 332633,
#  u'megadon-ag': 132611,
#  u'coolicool': 37813,
#  u'pogo-customer-service-number-1-844-446-4460-pogo-help-phone-number-some-times-pogo-games-4': 207,
#  u'braininfotech': 36247,
#  u'braininfotecj': 36299,
#  u'vechoe': 345905,
#  u'freerain-systems': 372092,
#  u'isharelife': 321325,
#  u'solon-mack-capital': 85608,
#  u'signonsite': 52889,
#  u'bright-willow': 67061,
#  u'sims-audio': 41938,
#  u'my-ranc': 102251,
#  u'zeom': 359601,
#  u'campact': 104438,
#  u'free-file-shredder': 131082,
#  u'moviecamp': 230553,
#  u'mini-attire': 66415,
#  u'usa-toll-free-1-855-463-6889-gmail-customer-service-live-chat-2': 35910,
#  u'usa-toll-free-1-855-463-6889-gmail-server-settings-for-outlook-2013': 36065,
#  u'threecandy': 291202,
#  u'fribi': 330159,
#  u'myskinpal': 79349,
#  u'trackthis': 403949,
#  u'avankia-llc': 185781,
#  u'ceton': 246034,
#  u'standard-luggage-co': 50549,
#  u'cy-send-mobile-top-up': 158435,
#  u'maremeua': 210791,
#  u'skinscience-institute-of-laser-esthetics-utah-county': 166994,
#  u'vericred-inc': 125667,
#  u'advertising-self-regulatory-council': 118019,
#  u'redfish-sa': 96532,
#  u'cvcertify': 358074,
#  u'quad-technologies': 40222,
#  u'945signals': 195175,
#  u'subscriptionbridge': 316945,
#  u'appseco-llc': 87585,
#  u'nuams': 187650,
#  u'general-machines': 317593,
#  u'phr-international-llc': 6497,
#  u'turvasana': 364158,
#  u'red-bulb-media': 373536,
#  u'merinews': 95936,
#  u'journal-of-corporation-law': 249688,
#  u'solutioninn': 320206,
#  u'webdweb': 312702,
#  u'pacific-rock-productions': 281567,
#  u'rhythm-necklace': 62477,
#  u'cyries-energy-inc': 185685,
#  u'fairways-investment-group': 237335,
#  u'the-way-of-h': 343384,
#  u'torofx': 55329,
#  u'recco-me': 322062,
#  u'zapworld': 301834,
#  u'anix-group': 387427,
#  u'inspire-pharmaceuticals': 360183,
#  u'simple-lifeforms': 394638,
#  u'moleskine': 350193,
#  u'resume-shoppe': 140021,
#  u'daisy-pi': 103999,
#  u'palazzo': 90047,
#  u'indicative': 222426,
#  u'capital-ca\xe7ambas': 28526,
#  u'drsdigital': 334019,
#  u'american-commitment': 128619,
#  u'dmvinfo1-com': 315625,
#  u'home-building-estimates': 32285,
#  u'elk-grove-locksmiths': 1123,
#  u'psychotactics': 81069,
#  u'amazon-app-store': 338765,
#  u'magic-software-enterprises': 352707,
#  u'baton-rouge-counseling': 206062,
#  u'drinkster': 305128,
#  u'castlebury-dental': 248721,
#  u'quiet-riots': 380009,
#  u'vpnet-technologies': 272434,
#  u'orange-capital-investment': 337066,
#  u'monroe-college-new-rochelle': 167266,
#  u'viridity-energy': 351121,
#  u'poolmania': 119012,
#  u'sdf-ventures': 98853,
#  u'isebox': 273474,
#  u'macworld-magazine': 357686,
#  u'helwan-university': 169940,
#  u'citizen-entrepreneurs': 119390,
#  u'vidhub': 88373,
#  u'lg-lugar-de-gente': 91252,
#  u'old-city-partners': 369034,
#  u'the-waypoint': 336142,
#  u'global-blood-therapeutics': 317902,
#  u'smart-box-design': 243693,
#  u'cardiology-surgery-hospital-india': 195521,
#  u'frum': 143097,
#  u'web-service-consulting': 197959,
#  u'mobsyte': 207190,
#  u'indicard': 105027,
#  u'bridge-37-ventures': 139410,
#  u'my-tv-shows': 386118,
#  u'\xd6zg\xfcweb-bal\u0131kesir-web-tasar\u0131m-hizmetleri': 107507,
#  u'windward-studios': 330051,
#  u'nexnet': 403166,
#  u'regus-3': 9299,
#  u'polroll': 145834,
#  u'faith-auto-glass-dallas': 165399,
#  u'dna': 229975,
#  u'template-software-inc': 278393,
#  u'bundeswehr-university-munich': 169805,
#  u'invent-network': 138547,
#  u'koenig-web-design': 273618,
#  u'club-de-innovaci\xf3n': 108671,
#  u'247transfer-com': 352859,
#  u'virgin-group': 204768,
#  u'grupo-liger': 72999,
#  u'kaptu': 229408,
#  u'marine-parts-express': 240239,
#  u'rezgateway': 28858,
#  u'environmental-financial-consulting-group': 44090,
#  u'mirinae-games': 84627,
#  u'andromeda-marketing-pvt-ltd': 358613,
#  u'vonage': 402180,
#  u'marketleverage': 65414,
#  u'girls-at-work': 353858,
#  u'asksales-biz': 151775,
#  u'hypnosis-subliminal': 240377,
#  u'miinto-dk': 362747,
#  u'ayotec': 392851,
#  u'transfermate-global-payments': 268338,
#  u'filosync': 112383,
#  u'retrievelt': 275498,
#  u'canadian-coast-guard': 33986,
#  u'smartlycom': 320521,
#  u'uxtalent': 282604,
#  u'winning-edge': 238047,
#  u'advanced-capital': 336826,
#  u'beaver-liquors': 85668,
#  u'hometownshop-technologies': 310528,
#  u'gf-capital-management-advisors': 152696,
#  u'continental-grain-company': 1825,
#  u'thirdeye': 101835,
#  u'kairos-transmedia': 124843,
#  u'sms-services': 267142,
#  u'founders-bank-of-loudoun': 363435,
#  u'cellgsmservice': 353851,
#  u'emobisoft': 333372,
#  u'perfect-apk': 162685,
#  u'99acres-com': 390427,
#  u'credit-karma': 406707,
#  u'creactivity-focus': 402514,
#  u'asociacin-de-pintores-con-la-boca-y-pie': 204040,
#  u'medical-simulation': 250071,
#  u'hudki': 323986,
#  u'giro-comunicacin': 209696,
#  u'tech-saviours': 70356,
#  u'quantum-anomaly-plt-radiant-power-chip': 43322,
#  u'doortonic': 64551,
#  u'assess-systems': 223379,
#  u'sparkbase': 394779,
#  u'regional-ophthalmic-surgeons-network': 272162,
#  u'vidneur': 308819,
#  u'imris-inc': 284575,
#  u'screenso': 238767,
#  u'marakon-associates': 9836,
#  u'cdl-truck-rental': 125823,
#  u'baby-joy': 331306,
#  u'shopifree': 330823,
#  u'mgap': 95917,
#  u'federal-polytechnic-ede': 59072,
#  u'the-sam-spiegel-film---television-school': 121597,
#  u'polski-standard-platnosci': 38959,
#  u'fur-and-mask': 145914,
#  u'pennyful-com': 342237,
#  u'complete-surrounds-landscaping': 201397,
#  u'meta-smarter-search': 59936,
#  u'iclarified': 242160,
#  u'2011-to': 4735,
#  u'chevrolet-pontiac': 225113,
#  u'seed-scientific-2': 94879,
#  u'whirlii': 298684,
#  u'impact-teen-drivers': 55033,
#  u'yourtripto': 300727,
#  u'mapr-technologies': 366049,
#  u'the-gig-city': 119246,
#  u'agncia-happy-tour': 230379,
#  u'terra-lycos-networks': 277199,
#  u'european-american-securities': 357326,
#  u'tape-tv': 355694,
#  u'voice-engineer-ireland': 109751,
#  u'emedz-com': 49006,
#  u'jivalti-inc': 246804,
#  u'david-stern-bail-bonds': 148643,
#  u'bia-kelsey-2': 91349,
#  u'inteleflow': 287495,
#  u'rflwebs': 40074,
#  u'honey-bs': 163754,
#  u'can-capital': 205468,
#  u'kt-rental-corp': 80095,
#  u'daf-hadash': 229522,
#  u'dormink-com': 317574,
#  u'wpide': 60565,
#  u'fihrst-management-services': 363233,
#  u'yellowstone': 152430,
#  u'the-medical-concierge-group': 455,
#  u'zipcash': 83548,
#  u'hellocafe': 107162,
#  u'karmelsonix': 262487,
#  u'dealsandyou-com': 373012,
#  u'united-employees-law-group---san-jose': 95577,
#  u'tagstoc': 403823,
#  u'carsten-institute': 168914,
#  u'haofangtong': 156678,
#  u'burnworld': 298694,
#  u'plain-text-offenders': 104975,
#  u'ugi-fit': 47414,
#  u'ring-inc': 71218,
#  u'integration-developer-network': 213139,
#  u'seton-medical-center': 271166,
#  u'ignite-social-enterprise': 193852,
#  u'ship-sticks': 317554,
#  u'access-to-money': 237893,
#  u'chain': 162942,
#  u'endomishra': 153877,
#  u'unripe-grape': 244927,
#  u'welike-2': 162704,
#  u'douglas-elliman-real-estate': 111679,
#  u'apex-inspection-solutions': 92337,
#  u'santa-barbara-business-college-bakersfield': 168036,
#  u'wyatt-company': 225932,
#  u'pace-company': 209448,
#  u'mcd-software-solutions': 364882,
#  u'cleanfuel-conversions': 207416,
#  u'micron-misting': 281342,
#  u'happycheckout': 90653,
#  u'jiangxi-province': 188600,
#  u'gustavus-adolphus-college': 170431,
#  u'take-portugal': 299447,
#  u'free-eboooks': 336913,
#  u'yy-inc': 320882,
#  u'personal-statement-service': 304880,
#  u'bio-ivt-group': 255701,
#  u'ge-transportation': 232685,
#  u'macho': 193229,
#  u'chessapeake': 334381,
#  u'into-the-lab-mobile': 355306,
#  u'andor-technology': 364427,
#  u'novadigm': 353843,
#  u'advanced-circulatory': 250585,
#  u'best-service-appliance-repair-staten-island': 135478,
#  u'jera': 61989,
#  u'propertyline': 397038,
#  u'booz-company': 371759,
#  u'dropboxee': 384623,
#  u'lifescape': 270801,
#  u'taskdoers': 323698,
#  u'new-england-biolabs': 234819,
#  u'logizent': 333381,
#  u'mediastream': 210821,
#  u'banters': 354924,
#  u'mesiab-labs': 374082,
#  u'xpressbuy': 39117,
#  u'dblur-technologies': 366682,
#  u'neil-gerber-eisenberg-llp': 117733,
#  u'bethere': 147549,
#  u'caredox': 342352,
#  u'wishexpress': 84863,
#  u'adpard-affiliate-network': 347918,
#  u'finer-things-in-tech': 58428,
#  u'hunter-bard': 332557,
#  u'warrington-scott-financial-consultants': 65187,
#  u'organon': 265780,
#  u'rubiconmd': 132846,
#  u'make-it-cheaper': 69773,
#  u'searchandise': 401071,
#  u'carolina-christian-radio': 370344,
#  u'ondeos': 65892,
#  u'fancast': 406823,
#  u'order-network': 284620,
#  u'mainframe-cloud': 851,
#  u'buus': 67857,
#  u'kik-friends': 58091,
#  u'wibee': 89282,
#  u'lionseye-group': 76468,
#  u'procuity': 70038,
#  u'casino-slot-games': 216427,
#  u'newedge-group': 256617,
#  u'burch': 692,
#  u'northleaf-capital-partners': 369445,
#  u'wgi-fund': 405334,
#  u'mivanti-systems': 400691,
#  u'e-digital-design': 351189,
#  u'eazieer': 298311,
#  u'inside-game-of-war': 104465,
#  u'pitchspace': 402537,
#  u'deep-identity': 181983,
#  u'isc-science': 201406,
#  u'strategic-management---media-group': 123989,
#  u'viewtru': 145892,
#  u'paris-green': 86041,
#  u'sree-chitra-thirunal-college-of-engineering': 172613,
#  u'numerouno-business-consultancy': 90293,
#  u'bowflex': 123912,
#  u'alliance-semiconductor': 362956,
#  u'headquarters-studios': 124892,
#  u'spartoo': 375638,
#  u'bumpn-inc': 84796,
#  u'cars-people': 353787,
#  u'vecta-software': 290132,
#  u'net-magazine': 37993,
#  u'homerun': 367716,
#  u'fluid-delivery-solutions': 148981,
#  u'eboss': 255722,
#  u'bridges-ventures': 378980,
#  u'union-gas-limited': 266849,
#  u'ebrand': 399522,
#  u'bittium': 18700,
#  u'slashtxt': 344955,
#  u'giveshop': 160051,
#  u'lbb-seed-capital-fund-gmbh': 295481,
#  u'ann-inc': 153337,
#  u'marinello-schools-of-beauty-fresno': 170376,
#  u'school-for-international-training': 167823,
#  u'south-university-columbia': 166608,
#  u'paperkut': 325935,
#  u'shapeone': 115392,
#  u'gaypon': 335323,
#  u'india-foundation-for-the-arts': 90120,
#  u'vsoft-technologies-pvt-ltd-': 113945,
#  u'imagimod': 161995,
#  u'sun-hung-kai-properties': 181680,
#  u'thumbmunkeys': 297194,
#  u'gorenje': 401713,
#  u'evena-medical': 228211,
#  u'cryptosense': 127664,
#  u'uflex': 14231,
#  u'ayuntamiento-de-madrid': 6618,
#  u'le-chic': 197352,
#  u'rhism': 242531,
#  u'videoiq': 385494,
#  u'delivery-dudes': 99980,
#  u'directorio-nuevo-polanco': 235287,
#  u'uniserve-communications': 276227,
#  u'roadadsindia': 52337,
#  u'travelbid-com-my': 359476,
#  u'sandstone-asset-management': 136391,
#  u'pineberry': 325358,
#  u'pricetree': 149508,
#  u'newcastle-college': 175900,
#  u'12lead': 232859,
#  u'geoaide-corporation': 93805,
#  u'coaps': 251490,
#  u'launch-tennessee-2': 26318,
#  u'luxola': 322161,
#  u'upperquad': 309265,
#  u'dax-automation': 319880,
#  u'catchthebest': 407561,
#  u'national-police-agency': 24044,
#  u'himily': 54337,
#  u'msa-the-safety-company': 11954,
#  u'orbio-solutions': 66421,
#  u'sportswurlz': 356146,
#  u'funding-profiles': 279248,
#  u'jeff-skoll-group': 109860,
#  u'misnomer-dance-thearter': 255657,
#  u'pyser-sgi-group': 28249,
#  u'claire-s-stores--inc-': 72357,
#  u'rent-a-car-now': 292997,
#  u'designing-digitally': 393480,
#  u'onyx-creative': 49499,
#  u'raah-financials-india-pvt-ltd': 54819,
#  u'le-petit-bistro': 19777,
#  u'smu-dedman-school-of-law': 101844,
#  u'pv-inova': 275750,
#  u'matter-of-form': 201224,
#  u'allexperts': 98009,
#  u'www-abcmedia-biz': 138860,
#  u'pro-ace-heating-cooling': 309184,
#  u'lygos-inc': 195673,
#  u'sierra-nevada-solar': 8191,
#  u'alantos': 85428,
#  u'et-tech': 286202,
#  u'true-time-tracker': 324259,
#  u'arc-computer': 155040,
#  u'ohio-city-power': 81766,
#  u'nounc-email-marketing': 366576,
#  u'barkibu': 137382,
#  u'tribus-real-estate-technologies': 353914,
#  u'sw-ventures': 91424,
#  u'logic-nation': 238120,
#  u'gilat-satcom': 198022,
#  u'irpac': 385265,
#  u'scary-cow-productions': 40199,
#  u'drinkpure': 11476,
#  u'system-verification-associates': 340656,
#  u'siemens-bmw': 280519,
#  u'northwestern-university-feinberg-school-of-medicine-chicago': 127909,
#  u'berlin-metropolitan-ventures': 290776,
#  u'pioneer-scientific': 157130,
#  u'the-pioneer': 399324,
#  u'chalk-drop': 326342,
#  u'freqseek': 360897,
#  u'maxim-group': 356170,
#  u'warp-drive-bio': 327652,
#  u'carespot': 310190,
#  u'huntley-garage-door-repair': 2084,
#  u'disney-abc-television-group': 165222,
#  u'iron-king-kennels': 229050,
#  u'groundreport': 406329,
#  u'art-hack-day': 92067,
#  u'pain-therapeutics': 285900,
#  u'institute-for-defense-analyses': 28378,
#  u'sum-digital-inc': 51435,
#  u'get-myo': 296098,
#  u'bufferbox': 324843,
#  u'wewez-com': 235457,
#  u'eshop-ventures': 144756,
#  u'liquent': 375885,
#  u'nova-specialty-hospitals': 313437,
#  u'hanson-mcclain': 79527,
#  u'itwin': 382987,
#  u'ezkie': 40988,
#  ...}

# %% [markdown]
# # Relationships

# %%
len(organizations_tot)
# Out:
# 408422

# %%
relationships = ['founders', 'board_members_and_advisors', 'investors', 'owned_by', 'headquarters', 'offices', 'categories', 'competitors', 'funding_rounds', 'investments', 'acquisitions', 'acquired_by', 'ipo']

relationships_infos = {}
relationships_infos['person'] = ['bio', 'born_on', 'permalink']
relationships_infos['address'] = ['city', 'country']
relationships_infos['market'] = ['name']
relationships_infos['product'] = ['name']
relationships_infos['organization'] = ['permalink']
relationships_infos['fundinground'] = ['announced_on', 'funding_type', 'money_raised_usd']
relationships_infos['acquisition'] = ['announced_on']
relationships_infos['ipo'] = ['went_public_on']

# %% [markdown]
# Script to extract features for each organizations, took 3min to run for 10 organizations.
# Estimated total execution time is:

# %%
2.5 * len(organizations_tot) / 10. / 60.
# Out:
# 1701.7583333333334

# %%
# %%time
#organizations_dict = {}
for i, permalink in enumerate(organizations_xlsx[331:1000]):
    if i%25 ==0:
        print 'iteration ', i, ' length is ', len(organizations_dict)
    infos = {}
    #permalink = organization['properties']['permalink']
    for relation in relationships:
        time.sleep(0.1)
        url = u'https://api.crunchbase.com/v/3/organizations/{}/{}?user_key={}'.format(permalink, relation, user_key)
        r_json = get_json(url)
        if 'data' not in r_json:
            continue
        if 'items' in r_json['data']:
            items = r_json['data']['items']
        elif 'item' in r_json['data']:
            items = r_json['data']['item']
        else:
            items = []
        number_pages = r_json['data']['paging']['number_of_pages']
        next_page_url = r_json['data']['paging']['next_page_url']
        for j in xrange(2, number_pages + 1):
            url = next_page_url[:-1]+str(j)+'&user_key='+user_key
            r_json = get_json(url)
            items += r_json['data']['items']
        
        relation_items = []
        if type(items) is dict:
            items = [items]
        for item in items:
            if 'relationships' in item:
                for relationships_key in item['relationships']:
                    relationships_key = relationships_key.lower()
                    if relationships_key in relationships_infos:
                        item_temp = {}
                        for infos_key in relationships_infos[relationships_key]:
                            item_temp[infos_key] = item['relationships'][relationships_key]['properties'][infos_key]
                        relation_items.append(item_temp)
            relationships_key = item['type'].lower()
            if relationships_key in relationships_infos:
                item_temp = {}
                for infos_key in relationships_infos[relationships_key]:
                    item_temp[infos_key] = item['properties'][infos_key]
                relation_items.append(item_temp)
        infos[relation] = relation_items
    organizations_dict[permalink] = infos

with open('tmp/organizations_dict.json', 'w') as f:
    json.dump(organizations_dict, f)
# Out:
# iteration  0  length is  331
# iteration  25  length is  356
# iteration  50  length is  381
# iteration  75  length is  406
# iteration  100  length is  431
# iteration  125  length is  456
# iteration  150  length is  481
# iteration  175  length is  506
# iteration  200  length is  531
# iteration  225  length is  556
# iteration  250  length is  581
# iteration  275  length is  606
# iteration  300  length is  631
# iteration  325  length is  656
# iteration  350  length is  681
# iteration  375  length is  706
# iteration  400  length is  731
# iteration  425  length is  756
# iteration  450  length is  781
# iteration  475  length is  806
# iteration  500  length is  831
# iteration  525  length is  856
# iteration  550  length is  881
# iteration  575  length is  906
# iteration  600  length is  931
# iteration  625  length is  956
# iteration  650  length is  981
# CPU times: user 3min 27s, sys: 13 s, total: 3min 40s
# Wall time: 2h 6min 2s

# %%
len(organizations_dict)
# Out:
# 1000

# %%
organizations_tot[0]['properties']['short_description']
# Out:
# u'ACT is the culmination of a long journey marked by the passion of its founder and its partners for Africa and its development.'

# %%
for o in organizations_dict:
    if o in permalink2index:
        i = permalink2index[o]
        organizations_dict[o]['short_description'] = organizations_tot[i]['properties']['short_description']

# %%
with open('tmp/organizations_dict.json', 'w') as f:
    json.dump(organizations_dict, f)

# %% [markdown]
# # Retrieving the information from the Excel dataset

# %%
from openpyxl import load_workbook
wb = load_workbook(filename='test.xlsx', read_only=True)
# Out:
# /usr/local/lib/python2.7/site-packages/openpyxl/workbook/names/named_range.py:124: UserWarning: Discarded range with reserved name
#   warnings.warn("Discarded range with reserved name")

# %%
wb.get_sheet_names()
# Out:
# [u'License',
#  u'Analysis',
#  u'Companies',
#  u'Rounds',
#  u'Investments',
#  u'Acquisitions',
#  u'Additions']

# %%
wc = wb['Companies']

# %%
organizations_xlsx = []
for row in enumerate(wc.rows):
    # Get rid of the first 14 characters which are '/organizations/'
    organizations_xlsx.append(row[1][0].value[14:])

# %%
# Removing the column name
organizations_xlsx.remove('')

# %%
len(organizations_xlsx)
# Out:
# 61399

# %%
with open('tmp/organizations_xlsx.json', 'w') as f:
    json.dump(organizations_xlsx, f)

# %% [markdown]
# # Summary of the scrapping

# %% [markdown]
# First, we scrapped all organizations name and short description from the REST API in the list 'organizations_tot', which gave 408 422 organizations and took 3h30. We had to sleep in between our API calls because the server could identify our API key and limit our call. This file is saved as a json in 'tmp/organizations_json.json', we mapped the company permalink (ie name in the REST API naming) with its index in the previous list for an easy access.
#
# Second, we had to retrieve the features we wanted from the REST API. The API is built around the relationships between the different instance (company, person, funding...) so we went through the different relationships and instance to store only the one we care about. This provided the list 'relationships', which stores the relationships we consider, and the dictionary 'relationships_infos' which stores for each instance type the attributes we consider. Once this preliminary work has been done, we wrote the API calls to store these attributes for each organizations. Trying it with our big list previously retrieved, we realized there were too many missing values and it would take too much time. As a result, we used the excel API to retrieve a list of companies name with at least some information. The excel API provides a list of 61 399 companies, with its categories, offices locations and funding informations (but there is nothing about the founders, the competitors, the board members...). Nonetheless, some information may be retrieved from the excel data as the locations and the funding, maybe we don't need to call the api for that (I didn't try it). This list is stored in the file 'organizations_xlsx.json'
#
# Third, we focused on the companies provided by the excel list and applied them the API calls routine to retrieve the different featurs. The first file contains 1000 companies and took 3 hours to run, the json is stored in 'organizations_dict.json'. It's a dictionary by permalink with attributes corresponding to the features we care about (some atributes are also dictionaries).
#
# ### Next step
#
# We need to write a routine to clean the features of the data: to interpret the text values (in the bio of the persons and in the short description of the company) which may contain relevant information, to decide what to do with missing data (maybe we could infer them based on simple averaging methods), to run first models to get a sense of which features are meaningful.
# Based on these insights we would be able to refine our features scrapping method and run it for more companies.
